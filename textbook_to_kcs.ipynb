# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from nltk.tokenize import TextTilingTokenizer
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### navigate to where your textbook is

# %%
os.chdir('/content/drive/My Drive')

# %% [markdown]
# ### The format of textbook.csv is just one chapter copied into each row. So this is n x 1 with no header in the first cell. First cell = first chapter.

# %%
df = pd.read_csv("textbook.csv", header = None)
print(len(df))
# Out:
# 16

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# !pip install --quiet --upgrade google-generativeai
import google.generativeai as genai
from tqdm import tqdm
import os

# %% [markdown]
# ### Insert Gemini API Key and select model

# %%
GEMINI_API_KEY = ""
genai.configure(api_key=GEMINI_API_KEY)


model = genai.GenerativeModel("gemini-2.0-flash")

# %% [markdown]
# ### In case extraction does not run through (e.g your notebook stops prematurely after 20 minutes), save all the outputs as txt files in a directory so if the txt exists it does not need to be regenerated.

# %%
result_directory = "/content/drive/MyDrive/gemini_labels_KClist_new"
os.makedirs(result_directory, exist_ok=True)

# %% [markdown]
# ### Feel Free to Edit Prompt as you see fit

# %%
def get_kc_label(segment, chapter_idx, segment_idx):
    filename = os.path.join(result_directory, f"{chapter_idx}_{segment_idx}_kc.txt")

    if os.path.exists(filename):
        return  # Already processed

    print(f"Processing Chapter {chapter_idx}, Segment {segment_idx}...")

    prompt = f"Summarize in 1–4 words the knowledge component described in this text:\n\n\"\"\"\n{segment}\n\"\"\""

    sleep(5)  # Prevent rate limit

    try:
        response = model.generate_content(prompt)
        label = response.text.strip()
    except Exception as e:
        print(f"Error at Chapter {chapter_idx}, Segment {segment_idx}: {e}")
        label = "error"

    with open(filename, "w") as f:
        f.write(label)

# %%
## chunks text into appropriate kcs through topic segmentation
def process_all_chapters(df):
    for chapter_idx in range(len(df)):
        chapter_text = df.iloc[chapter_idx, 0]

        try:
            segments = tt.tokenize(chapter_text)
        except Exception as e:
            print(f"Skipping Chapter {chapter_idx} due to error: {e}")
            continue

        for segment_idx, segment in enumerate(segments):
            get_kc_label(segment.strip(), chapter_idx, segment_idx)

# %%
process_all_chapters(df)
# Out:
# Processing Chapter 0, Segment 0...
# Processing Chapter 0, Segment 1...
# Processing Chapter 0, Segment 2...
# Processing Chapter 0, Segment 3...
# Processing Chapter 0, Segment 4...
# Processing Chapter 0, Segment 5...
# Processing Chapter 0, Segment 6...
# Processing Chapter 1, Segment 0...
# Processing Chapter 1, Segment 1...
# Processing Chapter 1, Segment 2...
# Processing Chapter 1, Segment 3...
# Processing Chapter 1, Segment 4...
# Processing Chapter 1, Segment 5...
# Processing Chapter 1, Segment 6...
# Processing Chapter 1, Segment 7...
# Processing Chapter 2, Segment 0...
# Processing Chapter 2, Segment 1...
# Processing Chapter 2, Segment 2...
# Processing Chapter 2, Segment 3...
# Processing Chapter 2, Segment 4...
# Processing Chapter 2, Segment 5...
# Processing Chapter 2, Segment 6...
# Processing Chapter 2, Segment 7...
# Processing Chapter 2, Segment 8...
# Processing Chapter 2, Segment 9...
# Processing Chapter 3, Segment 0...
# Processing Chapter 3, Segment 1...
# Processing Chapter 3, Segment 2...
# Processing Chapter 3, Segment 3...
# Processing Chapter 4, Segment 0...
# Processing Chapter 4, Segment 1...
# Processing Chapter 4, Segment 2...
# Processing Chapter 4, Segment 3...
# Processing Chapter 4, Segment 4...
# Processing Chapter 4, Segment 5...
# Processing Chapter 4, Segment 6...
# Processing Chapter 4, Segment 7...
# Processing Chapter 4, Segment 8...
# Processing Chapter 5, Segment 0...
# Processing Chapter 5, Segment 1...
# Processing Chapter 5, Segment 2...
# Processing Chapter 5, Segment 3...
# Processing Chapter 5, Segment 4...
# Processing Chapter 5, Segment 5...
# Processing Chapter 5, Segment 6...
# Processing Chapter 5, Segment 7...
# Processing Chapter 5, Segment 8...
# Processing Chapter 5, Segment 9...
# Processing Chapter 5, Segment 10...
# Processing Chapter 5, Segment 11...
# Processing Chapter 5, Segment 12...
# Processing Chapter 5, Segment 13...
# Processing Chapter 5, Segment 14...
# Processing Chapter 5, Segment 15...
# Processing Chapter 5, Segment 16...
# Processing Chapter 5, Segment 17...
# Processing Chapter 6, Segment 0...
# Processing Chapter 6, Segment 1...
# Processing Chapter 6, Segment 2...
# Processing Chapter 6, Segment 3...
# Processing Chapter 6, Segment 4...
# Processing Chapter 6, Segment 5...
# Processing Chapter 6, Segment 6...
# Processing Chapter 6, Segment 7...
# Processing Chapter 6, Segment 8...
# Processing Chapter 7, Segment 0...
# Processing Chapter 7, Segment 1...
# Processing Chapter 7, Segment 2...
# Processing Chapter 7, Segment 3...
# Processing Chapter 8, Segment 0...
# Processing Chapter 8, Segment 1...
# Processing Chapter 8, Segment 2...
# Processing Chapter 8, Segment 3...
# Processing Chapter 8, Segment 4...
# Processing Chapter 8, Segment 5...
# Processing Chapter 8, Segment 6...
# Processing Chapter 9, Segment 0...
# Processing Chapter 9, Segment 1...
# Processing Chapter 9, Segment 2...
# Processing Chapter 9, Segment 3...
# Processing Chapter 9, Segment 4...
# Processing Chapter 9, Segment 5...
# Processing Chapter 9, Segment 6...
# Processing Chapter 9, Segment 7...
# Processing Chapter 9, Segment 8...
# Processing Chapter 9, Segment 9...
# Processing Chapter 9, Segment 10...
# Processing Chapter 9, Segment 11...
# Processing Chapter 9, Segment 12...
# Processing Chapter 9, Segment 13...
# Processing Chapter 9, Segment 14...
# Processing Chapter 9, Segment 15...
# Processing Chapter 9, Segment 16...
# Processing Chapter 9, Segment 17...
# Processing Chapter 10, Segment 0...
# Processing Chapter 10, Segment 1...
# Processing Chapter 10, Segment 2...
# Processing Chapter 10, Segment 3...
# Processing Chapter 10, Segment 4...
# Processing Chapter 10, Segment 5...
# Processing Chapter 10, Segment 6...
# Processing Chapter 10, Segment 7...
# Processing Chapter 10, Segment 8...
# Processing Chapter 10, Segment 9...
# Processing Chapter 10, Segment 10...
# Processing Chapter 10, Segment 11...
# Processing Chapter 10, Segment 12...
# Processing Chapter 10, Segment 13...
# Processing Chapter 10, Segment 14...
# Processing Chapter 10, Segment 15...
# Processing Chapter 10, Segment 16...
# Processing Chapter 10, Segment 17...
# Processing Chapter 10, Segment 18...
# Processing Chapter 11, Segment 0...
# Processing Chapter 11, Segment 1...
# Processing Chapter 11, Segment 2...
# Processing Chapter 11, Segment 3...
# Processing Chapter 11, Segment 4...
# Processing Chapter 11, Segment 5...
# Processing Chapter 11, Segment 6...
# Processing Chapter 11, Segment 7...
# Processing Chapter 11, Segment 8...
# Processing Chapter 11, Segment 9...
# Processing Chapter 11, Segment 10...
# Processing Chapter 11, Segment 11...
# Processing Chapter 11, Segment 12...
# Processing Chapter 11, Segment 13...
# Processing Chapter 11, Segment 14...
# Processing Chapter 11, Segment 15...
# Processing Chapter 12, Segment 0...
# Processing Chapter 12, Segment 1...
# Processing Chapter 12, Segment 2...
# Processing Chapter 12, Segment 3...
# Processing Chapter 12, Segment 4...
# Processing Chapter 13, Segment 0...
# Processing Chapter 13, Segment 1...
# Processing Chapter 13, Segment 2...
# Processing Chapter 13, Segment 3...
# Processing Chapter 13, Segment 4...
# Processing Chapter 13, Segment 5...
# Processing Chapter 13, Segment 6...
# Processing Chapter 13, Segment 7...
# Processing Chapter 13, Segment 8...
# Processing Chapter 13, Segment 9...
# Processing Chapter 13, Segment 10...
# Processing Chapter 13, Segment 11...
# Processing Chapter 13, Segment 12...
# Processing Chapter 13, Segment 13...
# Processing Chapter 14, Segment 0...
# Processing Chapter 14, Segment 1...
# Processing Chapter 14, Segment 2...
# Processing Chapter 14, Segment 3...
# Processing Chapter 14, Segment 4...
# Processing Chapter 14, Segment 5...
# Processing Chapter 14, Segment 6...
# Processing Chapter 14, Segment 7...
# Processing Chapter 14, Segment 8...
# Processing Chapter 14, Segment 9...
# Processing Chapter 15, Segment 0...
# Processing Chapter 15, Segment 1...
# Processing Chapter 15, Segment 2...
# Processing Chapter 15, Segment 3...
# Processing Chapter 15, Segment 4...
# Processing Chapter 15, Segment 5...
# Processing Chapter 15, Segment 6...
# Processing Chapter 15, Segment 7...
# Processing Chapter 15, Segment 8...
# Processing Chapter 15, Segment 9...
# Processing Chapter 15, Segment 10...
# Processing Chapter 15, Segment 11...

# %%
import os
import pandas as pd
from nltk.tokenize import TextTilingTokenizer
## w and k are hyperparameters that govern kc fineness
tt = TextTilingTokenizer(w=50, k=170)
result_directory = "/content/drive/MyDrive/gemini_labels_KClist_new"

rows = []

for chapter_idx in range(len(df)):
    chapter_text = df.iloc[chapter_idx, 0]

    try:
        segments = tt.tokenize(chapter_text)
    except Exception as e:
        print(f"Skipping Chapter {chapter_idx} due to error: {e}")
        continue

    for segment_idx, segment in enumerate(segments):
        label_path = os.path.join(result_directory, f"{chapter_idx}_{segment_idx}_kc.txt")

        if os.path.exists(label_path):
            with open(label_path, "r") as f:
                kc_label = f.read().strip()
        else:
            kc_label = "missing"

        rows.append({
            "chapter_num": chapter_idx,
            "segment_text": segment.strip(),
            "kc_label": kc_label
        })

# Save CSV
output_csv_path = os.path.join(result_directory, "all_chapter_segments_with_kc.csv")
pd.DataFrame(rows).to_csv(output_csv_path, index=False)

# %% [markdown]
# ### This second run checks chunks are relevant for code and lets you filter out parts of textbook that shouldn't be a kc (e.g. history of the name "python")

# %%
from time import sleep

def is_relevant_to_solving(prompt_text):
    prompt = f"""
You are helping filter textbook content to assist students working on programming assignments.

Here is a piece of text. Only answer with 0 or 1. Is it directly helpful for writing a specific piece of code (e.g., solving a homework problem)?

- Answer **1** if the text contains a clear, concise explanation of a concept, coding principle, or logic that would directly help a student write or debug code for a specific problem.
- Answer **0** if the text provides general background, historical context, vague conceptual discussion, mismatched code/text, or anything not immediately actionable for solving a programming task.

Text:
\"\"\"{prompt_text}\"\"\"
"""
    try:
        sleep(5)
        response = model.generate_content(prompt)
        answer = response.text.strip().lower()

        if "1" in answer:
            print("1")
            return 1
        elif "0" in answer:
            print("0")
            return 0

        else:
            return -1  # unclear result
    except Exception as e:
        print(f"Error: {e}")
        return -1

kc_df = pd.read_csv(os.path.join(result_directory, "all_chapter_segments_with_kc.csv"))

relevant_flags = []

for i, row in kc_df.iterrows():
    segment = row['segment_text']
    print(f"Checking relevance for row {i}...")
    relevant = is_relevant_to_solving(segment)
    relevant_flags.append(relevant)

kc_df['relevant'] = relevant_flags

kc_df.to_csv(os.path.join(result_directory, "all_chapter_segments_with_kc_and_relevance.csv"), index=False)
print("✅ Relevance column added and CSV saved.")
# Out:
# Checking relevance for row 0...
# 0
# Checking relevance for row 1...
# 0
# Checking relevance for row 2...
# 1
# Checking relevance for row 3...
# 0
# Checking relevance for row 4...
# 1
# Checking relevance for row 5...
# 0
# Checking relevance for row 6...
# 1
# Checking relevance for row 7...
# 0
# Checking relevance for row 8...
# 1
# Checking relevance for row 9...
# 0
# Checking relevance for row 10...
# 1
# Checking relevance for row 11...
# 1
# Checking relevance for row 12...
# 1
# Checking relevance for row 13...
# 0
# Checking relevance for row 14...
# 1
# Checking relevance for row 15...
# 1
# Checking relevance for row 16...
# 1
# Checking relevance for row 17...
# 1
# Checking relevance for row 18...
# 1
# Checking relevance for row 19...
# 1
# Checking relevance for row 20...
# 1
# Checking relevance for row 21...
# 1
# Checking relevance for row 22...
# 0
# Checking relevance for row 23...
# 1
# Checking relevance for row 24...
# 1
# Checking relevance for row 25...
# 0
# Checking relevance for row 26...
# 1
# Checking relevance for row 27...
# 1
# Checking relevance for row 28...
# 1
# Checking relevance for row 29...
# 0
# Checking relevance for row 30...
# 1
# Checking relevance for row 31...
# 1
# Checking relevance for row 32...
# 1
# Checking relevance for row 33...
# 1
# Checking relevance for row 34...
# 1
# Checking relevance for row 35...
# 1
# Checking relevance for row 36...
# 1
# Checking relevance for row 37...
# 1
# Checking relevance for row 38...
# 0
# Checking relevance for row 39...
# 1
# Checking relevance for row 40...
# 1
# Checking relevance for row 41...
# 1
# Checking relevance for row 42...
# 1
# Checking relevance for row 43...
# 1
# Checking relevance for row 44...
# 1
# Checking relevance for row 45...
# 1
# Checking relevance for row 46...
# 1
# Checking relevance for row 47...
# 1
# Checking relevance for row 48...
# 1
# Checking relevance for row 49...
# 0
# Checking relevance for row 50...
# 1
# Checking relevance for row 51...
# 1
# Checking relevance for row 52...
# 1
# Checking relevance for row 53...
# 1
# Checking relevance for row 54...
# 1
# Checking relevance for row 55...
# 1
# Checking relevance for row 56...
# 1
# Checking relevance for row 57...
# 1
# Checking relevance for row 58...
# 1
# Checking relevance for row 59...
# 1
# Checking relevance for row 60...
# 1
# Checking relevance for row 61...
# 1
# Checking relevance for row 62...
# 1
# Checking relevance for row 63...
# 1
# Checking relevance for row 64...
# 1
# Checking relevance for row 65...
# 0
# Checking relevance for row 66...
# 1
# Checking relevance for row 67...
# 1
# Checking relevance for row 68...
# 1
# Checking relevance for row 69...
# 0
# Checking relevance for row 70...
# 1
# Checking relevance for row 71...
# 1
# Checking relevance for row 72...
# 1
# Checking relevance for row 73...
# 1
# Checking relevance for row 74...
# 1
# Checking relevance for row 75...
# 1
# Checking relevance for row 76...
# 1
# Checking relevance for row 77...
# 1
# Checking relevance for row 78...
# 1
# Checking relevance for row 79...
# 1
# Checking relevance for row 80...
# 1
# Checking relevance for row 81...
# 1
# Checking relevance for row 82...
# 1
# Checking relevance for row 83...
# 1
# Checking relevance for row 84...
# 1
# Checking relevance for row 85...
# 1
# Checking relevance for row 86...
# 1
# Checking relevance for row 87...
# 1
# Checking relevance for row 88...
# 1
# Checking relevance for row 89...
# 1
# Checking relevance for row 90...
# 1
# Checking relevance for row 91...
# 1
# Checking relevance for row 92...
# 1
# Checking relevance for row 93...
# 1
# Checking relevance for row 94...
# 0
# Checking relevance for row 95...
# 1
# Checking relevance for row 96...
# 1
# Checking relevance for row 97...
# 1
# Checking relevance for row 98...
# 1
# Checking relevance for row 99...
# 1
# Checking relevance for row 100...
# 1
# Checking relevance for row 101...
# 1
# Checking relevance for row 102...
# 1
# Checking relevance for row 103...
# 1
# Checking relevance for row 104...
# 1
# Checking relevance for row 105...
# 1
# Checking relevance for row 106...
# 1
# Checking relevance for row 107...
# 1
# Checking relevance for row 108...
# 1
# Checking relevance for row 109...
# 1
# Checking relevance for row 110...
# 1
# Checking relevance for row 111...
# 1
# Checking relevance for row 112...
# 1
# Checking relevance for row 113...
# 0
# Checking relevance for row 114...
# 1
# Checking relevance for row 115...
# 1
# Checking relevance for row 116...
# 1
# Checking relevance for row 117...
# 1
# Checking relevance for row 118...
# 1
# Checking relevance for row 119...
# 1
# Checking relevance for row 120...
# 1
# Checking relevance for row 121...
# 1
# Checking relevance for row 122...
# 1
# Checking relevance for row 123...
# 1
# Checking relevance for row 124...
# 1
# Checking relevance for row 125...
# 1
# Checking relevance for row 126...
# 1
# Checking relevance for row 127...
# 1
# Checking relevance for row 128...
# 1
# Checking relevance for row 129...
# 0
# Checking relevance for row 130...
# 1
# Checking relevance for row 131...
# 1
# Checking relevance for row 132...
# 1
# Checking relevance for row 133...
# 1
# Checking relevance for row 134...
# 1
# Checking relevance for row 135...
# 1
# Checking relevance for row 136...
# 1
# Checking relevance for row 137...
# 1
# Checking relevance for row 138...
# 1
# Checking relevance for row 139...
# 0
# Checking relevance for row 140...
# 1
# Checking relevance for row 141...
# 1
# Checking relevance for row 142...
# 0
# Checking relevance for row 143...
# 1
# Checking relevance for row 144...
# 1
# Checking relevance for row 145...
# 1
# Checking relevance for row 146...
# 1
# Checking relevance for row 147...
# 1
# Checking relevance for row 148...
# 1
# Checking relevance for row 149...
# 1
# Checking relevance for row 150...
# 1
# Checking relevance for row 151...
# 1
# Checking relevance for row 152...
# 1
# Checking relevance for row 153...
# 1
# Checking relevance for row 154...
# 0
# Checking relevance for row 155...
# 1
# Checking relevance for row 156...
# 1
# Checking relevance for row 157...
# 1
# Checking relevance for row 158...
# 1
# Checking relevance for row 159...
# 1
# Checking relevance for row 160...
# 1
# Checking relevance for row 161...
# 1
# Checking relevance for row 162...
# 1
# Checking relevance for row 163...
# 1
# Checking relevance for row 164...
# 1
# Checking relevance for row 165...
# 1
# Checking relevance for row 166...
# 1
# Checking relevance for row 167...
# 1
# Checking relevance for row 168...
# 1
# Checking relevance for row 169...
# 1
# ✅ Relevance column added and CSV saved.

# %%
#filters a final csv with only relevant items

input_csv = os.path.join(result_directory, "all_chapter_segments_with_kc_and_relevance.csv")
df = pd.read_csv(input_csv)

relevant_df = df[df['relevant'] == 1].copy()

output_csv = os.path.join(result_directory, "relevant_chapter_segments_only.csv")
relevant_df.to_csv(output_csv, index=False)

print(f"Saved filtered CSV with {len(relevant_df)} relevant segments to:\n{output_csv}")
# Out:
# ✅ Saved filtered CSV with 150 relevant segments to:
# /content/drive/MyDrive/gemini_labels_KClist_new/relevant_chapter_segments_only.csv
